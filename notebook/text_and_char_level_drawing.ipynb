# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path

import cv2 as cv
import imutils

from pathlib import Path

import cv2 as cv
import matplotlib
import matplotlib.pyplot as plt

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from datagen.imgen.transforms import functional as F
from datagen.imgen.transforms import effects as E
from datagen.imgen import transforms as T

matplotlib.rcParams['figure.figsize'] = (12,12)

# %%
from datagen.imgen.ops import imtext_ops
from datagen.imgen.content import draw

# %%
base_path = Path('../data/')
base_impath = str(base_path.joinpath('idcard/base3.png'))
base_image = cv.imread(base_impath, cv.IMREAD_UNCHANGED)

h,w = base_image.shape[:2]
w/2
# Out:
# 505.5

# %%
plt.imshow(base_image, cmap='gray')

# %%
img, data = draw.text_normal(base_image, "test", classname="PROVINSI",subclass="T", xy_pos=(100,100), font_size=40)
plt.imshow(img)

# %%
xmin, ymin = (100,100)
out_img, data = char_bbox(base_image, "Alamat", xy_pos=(xmin, ymin), debug_draw=True)
print(data)
plt.imshow(out_img);plt.show()

img, draw = imtext_ops.get_image_draw(out_img, img_mode="RGBA")
font = imtext_ops.get_image_font(font_name="ocra", font_size=fsize)
draw.text((xmin, ymin), text, font=font, fill=(0,0,0))

plt.imshow(np.array(img));
# Out:
# [([100, 109, 124, 135], 'A'), ([124, 109, 148, 135], 'l'), ([148, 116, 172, 135], 'a'), ([172, 116, 196, 135], 'm'), ([196, 116, 220, 135], 'a'), ([220, 110, 244, 135], 't')]

# %%
dlm_w
# Out:
# (24, 35)
